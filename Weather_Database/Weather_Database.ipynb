# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 603

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=" + weather_api_key
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=b55df7148abd1149c2375f623207582f

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description, 
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | bilma
# Processing Record 4 of Set 1 | noumea
# Processing Record 5 of Set 1 | hun
# Processing Record 6 of Set 1 | sao joao da barra
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | cockburn town
# Processing Record 10 of Set 1 | pierre
# Processing Record 11 of Set 1 | mahebourg
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | amarante do maranhao
# Processing Record 14 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 1 | druzhba
# Processing Record 16 of Set 1 | clyde river
# Processing Record 17 of Set 1 | itupiranga
# Processing Record 18 of Set 1 | asau
# Processing Record 19 of Set 1 | lugovoy
# Processing Record 20 of Set 1 | severo-kurilsk
# Processing Record 21 of Set 1 | norman wells
# Processing Record 22 of Set 1 | richards bay
# Processing Record 23 of Set 1 | bethel
# Processing Record 24 of Set 1 | yelniki
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | paamiut
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | bengkulu
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | bedesa
# Processing Record 33 of Set 1 | san quintin
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | longyearbyen
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | carrboro
# Processing Record 39 of Set 1 | esso
# Processing Record 40 of Set 1 | mayumba
# Processing Record 41 of Set 1 | talnakh
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | tres palos
# Processing Record 46 of Set 1 | udala
# Processing Record 47 of Set 1 | bell ville
# Processing Record 48 of Set 1 | marawi
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | panzhihua
# Processing Record 1 of Set 2 | bocaranga
# City not found. Skipping...
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | chokurdakh
# Processing Record 4 of Set 2 | saint anthony
# Processing Record 5 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | pendencias
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 2 | saint george
# Processing Record 12 of Set 2 | kodiak
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | terrace bay
# Processing Record 15 of Set 2 | souillac
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | pevek
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | chicama
# Processing Record 21 of Set 2 | chuy
# Processing Record 22 of Set 2 | gusau
# Processing Record 23 of Set 2 | torbay
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | kongolo
# Processing Record 26 of Set 2 | ulladulla
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | sao felix do xingu
# Processing Record 29 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 2 | tocopilla
# Processing Record 31 of Set 2 | carnarvon
# Processing Record 32 of Set 2 | finnsnes
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | svetlaya
# Processing Record 35 of Set 2 | sangar
# Processing Record 36 of Set 2 | sao filipe
# Processing Record 37 of Set 2 | vao
# Processing Record 38 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 39 of Set 2 | beloha
# Processing Record 40 of Set 2 | airai
# Processing Record 41 of Set 2 | shizunai
# Processing Record 42 of Set 2 | ballina
# Processing Record 43 of Set 2 | paicandu
# Processing Record 44 of Set 2 | arraial do cabo
# Processing Record 45 of Set 2 | goure
# Processing Record 46 of Set 2 | ergani
# Processing Record 47 of Set 2 | kaitangata
# Processing Record 48 of Set 2 | taoudenni
# Processing Record 49 of Set 2 | butaritari
# Processing Record 50 of Set 2 | pastavy
# Processing Record 1 of Set 3 | hovd
# Processing Record 2 of Set 3 | upernavik
# Processing Record 3 of Set 3 | olafsvik
# Processing Record 4 of Set 3 | puerto ayora
# Processing Record 5 of Set 3 | awbari
# Processing Record 6 of Set 3 | port elizabeth
# Processing Record 7 of Set 3 | hithadhoo
# Processing Record 8 of Set 3 | anderson
# Processing Record 9 of Set 3 | alofi
# Processing Record 10 of Set 3 | nouadhibou
# Processing Record 11 of Set 3 | coahuayana
# Processing Record 12 of Set 3 | qaqortoq
# Processing Record 13 of Set 3 | ancud
# Processing Record 14 of Set 3 | high level
# Processing Record 15 of Set 3 | koping
# Processing Record 16 of Set 3 | east london
# Processing Record 17 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 18 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 3 | yellowknife
# Processing Record 20 of Set 3 | kharp
# Processing Record 21 of Set 3 | lebu
# Processing Record 22 of Set 3 | finspang
# Processing Record 23 of Set 3 | bandarban
# Processing Record 24 of Set 3 | cefalu
# Processing Record 25 of Set 3 | yar-sale
# Processing Record 26 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 3 | chinhoyi
# Processing Record 28 of Set 3 | ypsonas
# Processing Record 29 of Set 3 | guanambi
# Processing Record 30 of Set 3 | codrington
# Processing Record 31 of Set 3 | gilbues
# Processing Record 32 of Set 3 | stokmarknes
# Processing Record 33 of Set 3 | katsuura
# Processing Record 34 of Set 3 | isangel
# Processing Record 35 of Set 3 | mehamn
# Processing Record 36 of Set 3 | henties bay
# Processing Record 37 of Set 3 | tevaitoa
# Processing Record 38 of Set 3 | kwekwe
# Processing Record 39 of Set 3 | vestmannaeyjar
# Processing Record 40 of Set 3 | saldanha
# Processing Record 41 of Set 3 | biak
# Processing Record 42 of Set 3 | vinh
# Processing Record 43 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 3 | rundu
# Processing Record 46 of Set 3 | senador canedo
# Processing Record 47 of Set 3 | arman
# Processing Record 48 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 49 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 50 of Set 3 | cidreira
# Processing Record 1 of Set 4 | osinovo
# Processing Record 2 of Set 4 | colac
# Processing Record 3 of Set 4 | teya
# Processing Record 4 of Set 4 | constitucion
# Processing Record 5 of Set 4 | geraldton
# Processing Record 6 of Set 4 | san cristobal
# Processing Record 7 of Set 4 | staryy nadym
# Processing Record 8 of Set 4 | ilulissat
# Processing Record 9 of Set 4 | panama city
# Processing Record 10 of Set 4 | nemuro
# Processing Record 11 of Set 4 | basco
# Processing Record 12 of Set 4 | udimskiy
# Processing Record 13 of Set 4 | paramonga
# Processing Record 14 of Set 4 | hervey bay
# Processing Record 15 of Set 4 | nhulunbuy
# Processing Record 16 of Set 4 | lazaro cardenas
# Processing Record 17 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 4 | saskylakh
# Processing Record 19 of Set 4 | mildura
# Processing Record 20 of Set 4 | avarua
# Processing Record 21 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 22 of Set 4 | baykit
# Processing Record 23 of Set 4 | mikkeli
# Processing Record 24 of Set 4 | victoria
# Processing Record 25 of Set 4 | santa maria
# Processing Record 26 of Set 4 | bambous virieux
# Processing Record 27 of Set 4 | praya
# Processing Record 28 of Set 4 | kinston
# Processing Record 29 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 4 | ukiah
# Processing Record 31 of Set 4 | kruisfontein
# Processing Record 32 of Set 4 | shelburne
# Processing Record 33 of Set 4 | nizhnevartovsk
# Processing Record 34 of Set 4 | bay roberts
# Processing Record 35 of Set 4 | numazu
# Processing Record 36 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 4 | barkot
# Processing Record 38 of Set 4 | esperance
# Processing Record 39 of Set 4 | ribeira grande
# Processing Record 40 of Set 4 | progreso
# Processing Record 41 of Set 4 | jenjarom
# Processing Record 42 of Set 4 | catuday
# Processing Record 43 of Set 4 | naze
# Processing Record 44 of Set 4 | hermanus
# Processing Record 45 of Set 4 | ranfurly
# Processing Record 46 of Set 4 | pangkalanbuun
# Processing Record 47 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 48 of Set 4 | illescas
# Processing Record 49 of Set 4 | matara
# Processing Record 50 of Set 4 | narasannapeta
# Processing Record 1 of Set 5 | manokwari
# Processing Record 2 of Set 5 | roebourne
# Processing Record 3 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 4 of Set 5 | ouesso
# Processing Record 5 of Set 5 | khatanga
# Processing Record 6 of Set 5 | uwayl
# City not found. Skipping...
# Processing Record 7 of Set 5 | solsvik
# City not found. Skipping...
# Processing Record 8 of Set 5 | provideniya
# Processing Record 9 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 10 of Set 5 | salalah
# Processing Record 11 of Set 5 | surt
# Processing Record 12 of Set 5 | neka
# Processing Record 13 of Set 5 | svetlyy
# Processing Record 14 of Set 5 | skiros
# City not found. Skipping...
# Processing Record 15 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 5 | harboore
# Processing Record 17 of Set 5 | lira
# Processing Record 18 of Set 5 | thinadhoo
# Processing Record 19 of Set 5 | shintomi
# Processing Record 20 of Set 5 | mana
# Processing Record 21 of Set 5 | kanel
# Processing Record 22 of Set 5 | manavalakurichi
# Processing Record 23 of Set 5 | tiksi
# Processing Record 24 of Set 5 | natal
# Processing Record 25 of Set 5 | thompson
# Processing Record 26 of Set 5 | itaituba
# Processing Record 27 of Set 5 | komsomolskiy
# Processing Record 28 of Set 5 | kazanskaya
# Processing Record 29 of Set 5 | amboasary
# Processing Record 30 of Set 5 | nanga eboko
# Processing Record 31 of Set 5 | padang
# Processing Record 32 of Set 5 | lubbock
# Processing Record 33 of Set 5 | hamilton
# Processing Record 34 of Set 5 | tuatapere
# Processing Record 35 of Set 5 | coquimbo
# Processing Record 36 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 5 | fort nelson
# Processing Record 38 of Set 5 | lata
# Processing Record 39 of Set 5 | skjervoy
# Processing Record 40 of Set 5 | gizo
# Processing Record 41 of Set 5 | georgetown
# Processing Record 42 of Set 5 | sabha
# Processing Record 43 of Set 5 | plettenberg bay
# Processing Record 44 of Set 5 | bandundu
# Processing Record 45 of Set 5 | santiago
# Processing Record 46 of Set 5 | tinglev
# Processing Record 47 of Set 5 | baracoa
# Processing Record 48 of Set 5 | kaeo
# Processing Record 49 of Set 5 | pontianak
# Processing Record 50 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 6 | pangai
# Processing Record 2 of Set 6 | fare
# Processing Record 3 of Set 6 | polson
# Processing Record 4 of Set 6 | westport
# Processing Record 5 of Set 6 | ongole
# Processing Record 6 of Set 6 | plymouth
# Processing Record 7 of Set 6 | vila
# Processing Record 8 of Set 6 | ponta delgada
# Processing Record 9 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 6 | ushtobe
# Processing Record 11 of Set 6 | katangli
# Processing Record 12 of Set 6 | chornyanka
# Processing Record 13 of Set 6 | nanortalik
# Processing Record 14 of Set 6 | itarema
# Processing Record 15 of Set 6 | lompoc
# Processing Record 16 of Set 6 | palmas
# Processing Record 17 of Set 6 | aiken
# Processing Record 18 of Set 6 | andenes
# Processing Record 19 of Set 6 | garoua
# Processing Record 20 of Set 6 | san isidro
# Processing Record 21 of Set 6 | gimbi
# Processing Record 22 of Set 6 | hasaki
# Processing Record 23 of Set 6 | carbonia
# Processing Record 24 of Set 6 | chara
# Processing Record 25 of Set 6 | karatau
# Processing Record 26 of Set 6 | jadu
# Processing Record 27 of Set 6 | guskhara
# Processing Record 28 of Set 6 | portland
# Processing Record 29 of Set 6 | sitka
# Processing Record 30 of Set 6 | hambantota
# Processing Record 31 of Set 6 | port hedland
# Processing Record 32 of Set 6 | coolum beach
# Processing Record 33 of Set 6 | asosa
# Processing Record 34 of Set 6 | marasesti
# Processing Record 35 of Set 6 | solnechnyy
# Processing Record 36 of Set 6 | nome
# Processing Record 37 of Set 6 | fukue
# Processing Record 38 of Set 6 | bantry
# Processing Record 39 of Set 6 | tasiilaq
# Processing Record 40 of Set 6 | babu
# Processing Record 41 of Set 6 | san patricio
# Processing Record 42 of Set 6 | juli
# Processing Record 43 of Set 6 | arcata
# Processing Record 44 of Set 6 | anbu
# Processing Record 45 of Set 6 | namibe
# Processing Record 46 of Set 6 | houma
# Processing Record 47 of Set 6 | waingapu
# Processing Record 48 of Set 6 | new bern
# Processing Record 49 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 50 of Set 6 | camacha
# Processing Record 1 of Set 7 | poum
# Processing Record 2 of Set 7 | riyadh
# Processing Record 3 of Set 7 | bagdarin
# Processing Record 4 of Set 7 | krasnoborsk
# Processing Record 5 of Set 7 | vostok
# Processing Record 6 of Set 7 | aklavik
# Processing Record 7 of Set 7 | ostrovnoy
# Processing Record 8 of Set 7 | kavieng
# Processing Record 9 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 10 of Set 7 | kimbe
# Processing Record 11 of Set 7 | mecca
# Processing Record 12 of Set 7 | shache
# Processing Record 13 of Set 7 | axim
# Processing Record 14 of Set 7 | likasi
# Processing Record 15 of Set 7 | minab
# Processing Record 16 of Set 7 | fairlie
# Processing Record 17 of Set 7 | yalutorovsk
# Processing Record 18 of Set 7 | ahipara
# Processing Record 19 of Set 7 | bradford
# Processing Record 20 of Set 7 | manoel urbano
# Processing Record 21 of Set 7 | kuching
# Processing Record 22 of Set 7 | qaanaaq
# Processing Record 23 of Set 7 | iwanai
# Processing Record 24 of Set 7 | huilong
# Processing Record 25 of Set 7 | anar darreh
# City not found. Skipping...
# Processing Record 26 of Set 7 | bolshoy uluy
# City not found. Skipping...
# Processing Record 27 of Set 7 | matiri
# Processing Record 28 of Set 7 | korla
# Processing Record 29 of Set 7 | ponta do sol
# Processing Record 30 of Set 7 | srednekolymsk
# Processing Record 31 of Set 7 | port augusta
# Processing Record 32 of Set 7 | hirado
# Processing Record 33 of Set 7 | lagoa
# Processing Record 34 of Set 7 | marsh harbour
# Processing Record 35 of Set 7 | harrisonburg
# Processing Record 36 of Set 7 | morehead
# Processing Record 37 of Set 7 | touros
# Processing Record 38 of Set 7 | pendleton
# Processing Record 39 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 40 of Set 7 | kudahuvadhoo
# Processing Record 41 of Set 7 | hefei
# Processing Record 42 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 7 | wamba
# Processing Record 44 of Set 7 | nacozari
# Processing Record 45 of Set 7 | grand gaube
# Processing Record 46 of Set 7 | bakchar
# Processing Record 47 of Set 7 | taseyevo
# Processing Record 48 of Set 7 | la libertad
# Processing Record 49 of Set 7 | dingle
# Processing Record 50 of Set 7 | broken hill
# Processing Record 1 of Set 8 | cedar city
# Processing Record 2 of Set 8 | manosque
# Processing Record 3 of Set 8 | brae
# Processing Record 4 of Set 8 | vila franca do campo
# Processing Record 5 of Set 8 | grindavik
# Processing Record 6 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 7 of Set 8 | taybad
# Processing Record 8 of Set 8 | chandrakona
# Processing Record 9 of Set 8 | iqaluit
# Processing Record 10 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 8 | chapais
# Processing Record 12 of Set 8 | mareeba
# Processing Record 13 of Set 8 | husavik
# Processing Record 14 of Set 8 | gazli
# Processing Record 15 of Set 8 | songjianghe
# Processing Record 16 of Set 8 | bairiki
# Processing Record 17 of Set 8 | gannan
# Processing Record 18 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 19 of Set 8 | coihaique
# Processing Record 20 of Set 8 | kattivakkam
# Processing Record 21 of Set 8 | koygorodok
# Processing Record 22 of Set 8 | elko
# Processing Record 23 of Set 8 | pisco
# Processing Record 24 of Set 8 | sisimiut
# Processing Record 25 of Set 8 | pasco
# Processing Record 26 of Set 8 | yashan
# Processing Record 27 of Set 8 | gikongoro
# Processing Record 28 of Set 8 | trinidad
# Processing Record 29 of Set 8 | yeppoon
# Processing Record 30 of Set 8 | mount gambier
# Processing Record 31 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 8 | tallahassee
# Processing Record 33 of Set 8 | jiexiu
# Processing Record 34 of Set 8 | evanston
# Processing Record 35 of Set 8 | gilroy
# Processing Record 36 of Set 8 | keskin
# Processing Record 37 of Set 8 | banmo
# City not found. Skipping...
# Processing Record 38 of Set 8 | sarangani
# Processing Record 39 of Set 8 | avera
# Processing Record 40 of Set 8 | verkhoyansk
# Processing Record 41 of Set 8 | cabo san lucas
# Processing Record 42 of Set 8 | wattegama
# Processing Record 43 of Set 8 | san pedro
# Processing Record 44 of Set 8 | byron bay
# Processing Record 45 of Set 8 | buchanan
# Processing Record 46 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 8 | sorong
# Processing Record 48 of Set 8 | ishigaki
# Processing Record 49 of Set 8 | tottori
# Processing Record 50 of Set 8 | kyzyl-suu
# Processing Record 1 of Set 9 | dhandhuka
# Processing Record 2 of Set 9 | brainerd
# Processing Record 3 of Set 9 | caravelas
# Processing Record 4 of Set 9 | markdale
# Processing Record 5 of Set 9 | juneau
# Processing Record 6 of Set 9 | puerto quijarro
# Processing Record 7 of Set 9 | rovaniemi
# Processing Record 8 of Set 9 | leningradskiy
# Processing Record 9 of Set 9 | rocha
# Processing Record 10 of Set 9 | faanui
# Processing Record 11 of Set 9 | umm kaddadah
# Processing Record 12 of Set 9 | demirci
# Processing Record 13 of Set 9 | vanimo
# Processing Record 14 of Set 9 | shimoda
# Processing Record 15 of Set 9 | lamu
# Processing Record 16 of Set 9 | sumbe
# Processing Record 17 of Set 9 | fria
# Processing Record 18 of Set 9 | eyl
# Processing Record 19 of Set 9 | ferrol
# Processing Record 20 of Set 9 | mogadishu
# Processing Record 21 of Set 9 | chernyshevskiy
# Processing Record 22 of Set 9 | omboue
# Processing Record 23 of Set 9 | almaznyy
# Processing Record 24 of Set 9 | bella union
# Processing Record 25 of Set 9 | fairbanks
# Processing Record 26 of Set 9 | port macquarie
# Processing Record 27 of Set 9 | pak chong
# Processing Record 28 of Set 9 | aykhal
# Processing Record 29 of Set 9 | murgab
# Processing Record 30 of Set 9 | kubinka
# Processing Record 31 of Set 9 | awjilah
# Processing Record 32 of Set 9 | isla mujeres
# Processing Record 33 of Set 9 | maragogi
# Processing Record 34 of Set 9 | tilichiki
# Processing Record 35 of Set 9 | wheatley
# Processing Record 36 of Set 9 | barra do garcas
# Processing Record 37 of Set 9 | cody
# Processing Record 38 of Set 9 | kashi
# Processing Record 39 of Set 9 | barcelos
# Processing Record 40 of Set 9 | sogne
# Processing Record 41 of Set 9 | mackay
# Processing Record 42 of Set 9 | locri
# Processing Record 43 of Set 9 | kyra
# Processing Record 44 of Set 9 | kassala
# Processing Record 45 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 9 | mezen
# Processing Record 47 of Set 9 | acajutla
# Processing Record 48 of Set 9 | chiredzi
# Processing Record 49 of Set 9 | qiongshan
# Processing Record 50 of Set 9 | kati
# Processing Record 1 of Set 10 | novorudnyy
# Processing Record 2 of Set 10 | zhongxing
# Processing Record 3 of Set 10 | kieta
# Processing Record 4 of Set 10 | tupancireta
# Processing Record 5 of Set 10 | kostino
# Processing Record 6 of Set 10 | sindand
# City not found. Skipping...
# Processing Record 7 of Set 10 | athabasca
# Processing Record 8 of Set 10 | san andres
# Processing Record 9 of Set 10 | kavaratti
# Processing Record 10 of Set 10 | robertsport
# Processing Record 11 of Set 10 | imeni poliny osipenko
# Processing Record 12 of Set 10 | alice springs
# Processing Record 13 of Set 10 | berlevag
# Processing Record 14 of Set 10 | alpena
# Processing Record 15 of Set 10 | pitogo
# Processing Record 16 of Set 10 | maxixe
# Processing Record 17 of Set 10 | puerto baquerizo moreno
# Processing Record 18 of Set 10 | laukaa
# Processing Record 19 of Set 10 | lorengau
# Processing Record 20 of Set 10 | aksu
# Processing Record 21 of Set 10 | kingman
# Processing Record 22 of Set 10 | khanewal
# Processing Record 23 of Set 10 | guerrero negro
# Processing Record 24 of Set 10 | marsa matruh
# Processing Record 25 of Set 10 | antalaha
# Processing Record 26 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 27 of Set 10 | suileng
# Processing Record 28 of Set 10 | elat
# Processing Record 29 of Set 10 | lavrentiya
# Processing Record 30 of Set 10 | rio gallegos
# Processing Record 31 of Set 10 | havoysund
# Processing Record 32 of Set 10 | pachora
# Processing Record 33 of Set 10 | seoul
# Processing Record 34 of Set 10 | payo
# Processing Record 35 of Set 10 | bathsheba
# Processing Record 36 of Set 10 | lasa
# Processing Record 37 of Set 10 | zhezkazgan
# Processing Record 38 of Set 10 | rio bueno
# Processing Record 39 of Set 10 | nabire
# Processing Record 40 of Set 10 | yalta
# Processing Record 41 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 10 | starodub
# Processing Record 43 of Set 10 | comodoro rivadavia
# Processing Record 44 of Set 10 | maceio
# Processing Record 45 of Set 10 | upata
# Processing Record 46 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 10 | puerto del rosario
# Processing Record 48 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 10 | college
# Processing Record 50 of Set 10 | ahuimanu
# Processing Record 1 of Set 11 | kenora
# Processing Record 2 of Set 11 | mendoza
# Processing Record 3 of Set 11 | sohag
# Processing Record 4 of Set 11 | ourossogui
# Processing Record 5 of Set 11 | mitsamiouli
# Processing Record 6 of Set 11 | ekangala
# Processing Record 7 of Set 11 | el seibo
# Processing Record 8 of Set 11 | bandarbeyla
# Processing Record 9 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 10 of Set 11 | san ramon
# Processing Record 11 of Set 11 | narsaq
# Processing Record 12 of Set 11 | luderitz
# Processing Record 13 of Set 11 | the valley
# Processing Record 14 of Set 11 | pangnirtung
# Processing Record 15 of Set 11 | vrangel
# Processing Record 16 of Set 11 | camalu
# Processing Record 17 of Set 11 | bintulu
# Processing Record 18 of Set 11 | lake city
# Processing Record 19 of Set 11 | isabela
# Processing Record 20 of Set 11 | dien bien
# City not found. Skipping...
# Processing Record 21 of Set 11 | zhigansk
# Processing Record 22 of Set 11 | lisakovsk
# Processing Record 23 of Set 11 | brechin
# Processing Record 24 of Set 11 | acapulco
# Processing Record 25 of Set 11 | kanganpur
# Processing Record 26 of Set 11 | mitla
# Processing Record 27 of Set 11 | lar gerd
# City not found. Skipping...
# Processing Record 28 of Set 11 | mao
# Processing Record 29 of Set 11 | kitami
# Processing Record 30 of Set 11 | potchefstroom
# Processing Record 31 of Set 11 | terney
# Processing Record 32 of Set 11 | mahina
# Processing Record 33 of Set 11 | aksay
# Processing Record 34 of Set 11 | deputatskiy
# Processing Record 35 of Set 11 | carros
# Processing Record 36 of Set 11 | fortuna
# Processing Record 37 of Set 11 | beinamar
# Processing Record 38 of Set 11 | beidao
# Processing Record 39 of Set 11 | jalu
# Processing Record 40 of Set 11 | lhokseumawe
# Processing Record 41 of Set 11 | guaruja
# Processing Record 42 of Set 11 | nehe
# Processing Record 43 of Set 11 | balykshi
# Processing Record 44 of Set 11 | melo
# Processing Record 45 of Set 11 | ossora
# Processing Record 46 of Set 11 | kalmthout
# Processing Record 47 of Set 11 | saint-augustin
# Processing Record 48 of Set 11 | shkotovo-22
# City not found. Skipping...
# Processing Record 49 of Set 11 | guilin
# Processing Record 50 of Set 11 | safaga
# Processing Record 1 of Set 12 | sola
# Processing Record 2 of Set 12 | nador
# Processing Record 3 of Set 12 | gijon
# Processing Record 4 of Set 12 | port lincoln
# Processing Record 5 of Set 12 | ust-kuyga
# Processing Record 6 of Set 12 | mangrol
# Processing Record 7 of Set 12 | saumur
# Processing Record 8 of Set 12 | moranbah
# Processing Record 9 of Set 12 | charters towers
# Processing Record 10 of Set 12 | kargasok
# Processing Record 11 of Set 12 | itacoatiara
# Processing Record 12 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 12 | xining
# Processing Record 14 of Set 12 | port hueneme
# Processing Record 15 of Set 12 | arlit
# Processing Record 16 of Set 12 | jurm
# Processing Record 17 of Set 12 | hay river
# Processing Record 18 of Set 12 | weligama
# Processing Record 19 of Set 12 | sembe
# Processing Record 20 of Set 12 | rye
# Processing Record 21 of Set 12 | sinnamary
# Processing Record 22 of Set 12 | ibra
# Processing Record 23 of Set 12 | novyy urengoy
# Processing Record 24 of Set 12 | kirakira
# Processing Record 25 of Set 12 | pemangkat
# Processing Record 26 of Set 12 | porto santo
# Processing Record 27 of Set 12 | karaton
# Processing Record 28 of Set 12 | berea
# Processing Record 29 of Set 12 | balsas
# Processing Record 30 of Set 12 | talaya
# Processing Record 31 of Set 12 | karratha
# Processing Record 32 of Set 12 | ferkessedougou
# Processing Record 33 of Set 12 | nileshwar
# Processing Record 34 of Set 12 | lahad datu
# Processing Record 35 of Set 12 | campos gerais
# Processing Record 36 of Set 12 | xiuyan
# Processing Record 37 of Set 12 | tessalit
# Processing Record 38 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 12 | lac du bonnet
# Processing Record 41 of Set 12 | ojinaga
# Processing Record 42 of Set 12 | bayan
# Processing Record 43 of Set 12 | alta floresta
# Processing Record 44 of Set 12 | altar
# Processing Record 45 of Set 12 | vila velha
# Processing Record 46 of Set 12 | mollendo
# Processing Record 47 of Set 12 | ruidoso
# Processing Record 48 of Set 12 | arroyo
# Processing Record 49 of Set 12 | anadyr
# Processing Record 50 of Set 12 | hofn
# Processing Record 1 of Set 13 | marfino
# Processing Record 2 of Set 13 | roald
# Processing Record 3 of Set 13 | cortes
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 548

# %%
#Convert the array of dictionaries to a Pandas DataFrame.

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Ushuaia      AR -54.8000  -68.3000    277.96        81
# 1        Tuktoyaktuk      CA  69.4541 -133.0374    282.15        81
# 2              Bilma      NE  18.6853   12.9164    301.44        58
# 3             Noumea      NC -22.2763  166.4572    299.14        99
# 4                Hun      LY  29.1268   15.9477    297.78        44
# 5  Sao Joao Da Barra      BR -21.6403  -41.0511    293.34        85
# 6         Nikolskoye      RU  59.7035   30.7861    289.75        75
# 7          Jamestown      US  42.0970  -79.2353    295.92        74
# 8      Cockburn Town      TC  21.4612  -71.1419    300.46        77
# 9             Pierre      US  44.3683 -100.3510    297.62        56
#
#    Cloudiness  Wind Speed Current Description                 Date
# 0          75        8.23          light rain  2022-07-28 03:38:00
# 1         100        5.14     overcast clouds  2022-07-28 03:41:28
# 2          81        3.90       broken clouds  2022-07-28 03:41:29
# 3         100        3.55     overcast clouds  2022-07-28 03:36:49
# 4           0        2.71           clear sky  2022-07-28 03:41:30
# 5           0        4.74           clear sky  2022-07-28 03:41:31
# 6           0        2.04           clear sky  2022-07-28 03:41:31
# 7         100        3.09     overcast clouds  2022-07-28 03:39:49
# 8           0        9.35           clear sky  2022-07-28 03:38:44
# 9          20        5.66          few clouds  2022-07-28 03:41:32

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
